# %%
import sqlite3

# %%
db_path = "/Users/vancefeng/Desktop/ords/AML/spotify_analysis_project/data/task1/spotify_database.db"

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("\nTables in database:")
for t in tables:
    print(" -", t[0])
# Out:
# Tables in database:
#  - spotify_data
#  - KmeanSample2021
#  - KmeanSample2022Test
#  - KmeanSample
#  - KmeanSample2021Train
#  - KmeanSample2022Val
#  - KmeansClusteredResults

# %%
for t in tables:
    table_name = t[0]
    print(f"\nSchema for table: {table_name}")
    cursor.execute(f"PRAGMA table_info({table_name});")
    for col in cursor.fetchall():
        cid, name, col_type, notnull, default_val, pk = col
        print(f"  {name} ({col_type}){' [PK]' if pk else ''}")
# Out:
# Schema for table: spotify_data
#   Rank (INTEGER)
#   Title (TEXT)
#   Artists (TEXT)
#   Date (TIMESTAMP)
#   Danceability (REAL)
#   Energy (REAL)
#   Loudness (REAL)
#   Speechiness (REAL)
#   Acousticness (REAL)
#   Instrumentalness (REAL)
#   Valence (REAL)
#   # of Artist (TEXT)
#   Artist (Ind.) (TEXT)
#   # of Nationality (TEXT)
#   Nationality (TEXT)
#   Continent (TEXT)
#   Points (Total) (INTEGER)
#   Points (Ind for each Artist/Nat) (REAL)
#   id (TEXT)
#   Song URL (TEXT)
#   ArtistOrder (INTEGER)
#   NationalityOrder (INTEGER)
#
# Schema for table: KmeanSample2021
#   Title (TEXT)
#   Artists (TEXT)
#   Danceability (REAL)
#   Energy (REAL)
#   Loudness (REAL)
#   Speechiness (REAL)
#   Acousticness (REAL)
#   Instrumentalness (REAL)
#   Valence (REAL)
#   Points (Total) (INTEGER)
#
# Schema for table: KmeanSample2022Test
#   Title (TEXT)
#   Artists (TEXT)
#   Danceability (REAL)
#   Energy (REAL)
#   Loudness (REAL)
#   Speechiness (REAL)
#   Acousticness (REAL)
#   Instrumentalness (REAL)
#   Valence (REAL)
#   Points (Total) (INTEGER)
#
# Schema for table: KmeanSample
#   Title (TEXT)
#   Artists (TEXT)
#   Danceability (REAL)
#   Energy (REAL)
#   Loudness (REAL)
#   Speechiness (REAL)
#   Acousticness (REAL)
#   Instrumentalness (REAL)
#   Valence (REAL)
#
# Schema for table: KmeanSample2021Train
#   Title (TEXT)
#   Artists (TEXT)
#   Danceability (REAL)
#   Energy (REAL)
#   Loudness (REAL)
#   Speechiness (REAL)
#   Acousticness (REAL)
#   Instrumentalness (REAL)
#   Valence (REAL)
#
# Schema for table: KmeanSample2022Val
#   Title (TEXT)
#   Artists (TEXT)
#   Danceability (REAL)
#   Energy (REAL)
#   Loudness (REAL)
#   Speechiness (REAL)
#   Acousticness (REAL)
#   Instrumentalness (REAL)
#   Valence (REAL)
#
# Schema for table: KmeansClusteredResults
#   Title (TEXT)
#   Artists (TEXT)
#   Danceability (REAL)
#   Energy (REAL)
#   Loudness (REAL)
#   Speechiness (REAL)
#   Acousticness (REAL)
#   Instrumentalness (REAL)
#   Valence (REAL)
#   cluster_id (INTEGER)
#   cluster_label (TEXT)
#   style_description (TEXT)
